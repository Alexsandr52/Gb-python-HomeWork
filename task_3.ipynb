# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
theta = np.linspace(0, 2 * np.pi, 100)
r = 1
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.plot(x, y)
plt.axis('scaled')
plt.grid(True)

# %%
theta = np.linspace(0, 2 * np.pi, 100)
r = 1
x = r * np.cos(theta)
y = r * np.sin(theta)
plt.grid(True)
plt.plot(x/7, y/15)
plt.axis('scaled')
# Out:
# (-0.1570673385003349,
#  0.15713926101702275,
#  -0.07332410269608418,
#  0.07332410269608418)

# %%
theta = np.linspace(0, 10, 100)
r = 1
x = theta
y = 1/theta

plt.plot(x, y)
plt.plot(-x, -y)
plt.axis('scaled')
plt.grid(True)
# Out:
# C:\Users\alexx\AppData\Local\Temp\ipykernel_13388\4197840469.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   y = 1/theta
