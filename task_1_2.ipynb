# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 100)
y = np.cos(x)
y2 = np.cos(x - 10) + 2
y3 = 0.5 * np.cos(x - 15) + 3
plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)
